# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df = pd.read_csv(r"C:\Users\anith\Downloads\Visa.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path='visa.csv'
visa_df = pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **frequency table**

# %%
keys= visa_df['continent'].value_counts().keys()
values= visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
                columns=['labels','No of appilications'])
df.to_csv('continent.csv',index=False)

# %% [markdown]
# - I want to create all frequency tables
# - and save in a new folder
# - The folder is available
# - all steps automate

# %% [markdown]
# **step-1: Create a folder using python code**

# %%
import os
try:
   os.makedirs('frequency_table')
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'frequency_table'

# %%
os.makedirs('frequency_table1',exist_ok=True)

# %%
keys= visa_df ['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
                columns=['labels','No of appilications'])
#Absolute path
path=r"C:\Users\anith\OneDrive\Desktop\Pictures\Documents\Anitha\data1.csv"
df.to_csv(path,index=False)

# %%
#relative path
path=r'./frequency_table\continent1.csv'
df.to_csv(path,index=False)

# %%
cwd=os.getcwd()
cwd
# Out:
# 'C:\\Users\\anith'

# %%
cwd=os.getcwd()
folder_name='frequency_table'
new_dir=os.path.join(cwd,folder_name)
filename='continent2.csv'
path=os.path.join(new_dir,filename)
df.to_csv(path,index=False)

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
print(visa_df.columns)
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#step-1
keys= visa_df['continent'].value_counts().keys()
values= visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
                columns=['labels','No of appilications'])
#step-2
folder_name='frequency_table'
os.makedirs(folder_name,exist_ok=True)

#step-3
cwd=os.getcwd()
folder_name='frequency_table'
new_dir=os.path.join(cwd,folder_name)
filename='continent2.csv'
path=os.path.join(new_dir,filename)

#step-4
df.to_csv(path,index=False)

# %%
#step-1
for i in cat[:1]:
 keys= visa_df[i].value_counts().keys()
 values= visa_df[i].value_counts().values
 df=pd.DataFrame(zip(keys,values),
                columns=['labels','No of appilications'])
#step-2
folder_name='frequency_table'
os.makedirs(folder_name,exist_ok=True)

#step-3
cwd=os.getcwd()
folder_name='frequency_table'
new_dir=os.path.join(cwd,folder_name)
filename=f'{i}.csv'
path=os.path.join(new_dir,filename)

#step-4
df.to_csv(path,index=False)

# %% [markdown]
# **Bar Charts Automate**

# %%
keys= visa_df['continent'].value_counts().keys()
values= visa_df['continent'].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('lables')
plt.ylabel('count')
plt.title('continent_barchart')
plt.savefig('continent_bar.jpg')

# %%
#step-1:
for i in cat [1:]:
    keys= visa_df[i].value_counts().keys()
    values= visa_df[i].value_counts().values
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)
    plt.xlabel('lables')
    plt.ylabel('count')
    plt.title(f'{i}barchart')
    plt.savefig(f'{i}bar.jpg')

# %%
for i in cat[1:]:
    keys= visa_df[i].value_counts().keys()
    values= visa_df[i].value_counts().values
    plt.pie(values,explode=[0.1 for i in range(len(keys))],labels=keys,autopct="%0.2f%%",startangle=90,radius=2)
    plt.show()

# %%
#import the packages
# read the data
# divide into cat num coumns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path='visa.csv'
visa_df = pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#bar chart for continen
keys= visa_df['continent'].value_counts().keys()
values= visa_df['continent'].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys,values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# **subplots**
# - multiplots we can plot in a single area

# %%
plt.subplot(2,2,1)
plt.title('2-2-1')
plt.subplot(2,2,2)
plt.title('2-2-2')
plt.subplot(2,2,3)
plt.title('2-2-3')
plt.subplot(2,2,4)
plt.title('2-2-4')
# Out:
# Text(0.5, 1.0, '2-2-4')

# %%
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
plt.subplot(3,1,1)
plt.subplot(3,1,2)
plt.subplot(3,1,3)
# Out:
# <Axes: >

# %%
# I want to draw total 9 cat cols are there
# in that we should not consider case id
# so remaining 8 columns so we need 8 plots
# (1,8) or (8,1) or (2,4) or (4,2) or (3,3)

# %%
#plt.subplot(2,2,1)
#plt.subplot(2,2,1)
#plt.subplot(2,2,3)
#plt.subplot(2,2,4)

#plt.supplot(2,2,i)
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
# plt.subplot(2,2,i)
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
plt.figure(figsize=(16,8))
for i in range(1,len(cat)):
    
   keys= visa_df[cat[i]].value_counts().keys()
   values= visa_df[cat[i]].value_counts().values
   plt.figure(figsize=(10,4))
   plt.subplot(3,3,i)
   plt.bar(keys,values)

# %%
plt.figure(figsize=(16,8))
for i in range(1,len(cat)):
    
   keys= visa_df[cat[i]].value_counts().keys()
   values= visa_df[cat[i]].value_counts().values
   
   plt.subplot(3,3,i)
   plt.bar(keys,values)

# %%
plt.figure(figsize=(20,10))
for i in range(1,len(cat)):
    
   keys= visa_df[cat[i]].value_counts().keys()
   values= visa_df[cat[i]].value_counts().values
   
   plt.subplot(3,3,i).bar(keys,values)

# %%
 plt.figure(figsize=(20,10))
for i in range(1,len(cat)):
    
   keys= visa_df[cat[i]].value_counts().keys()
   values= visa_df[cat[i]].value_counts().values
   plt.subplot(3,3,i).bar(keys,values)
   plt.title(f'{cat[i]}_bar_chart')
   plt.suptitle('Barcharts')

# %%
**
