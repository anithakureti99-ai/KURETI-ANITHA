# %%
a=10
b=20
c=30
c=a+b
print(c)
# Out:
# 30

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path='visa.csv'
visa_df = pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
- we have two types of scaling
- z score(standardization)
- Min max scalar(Normalization)
# Out:
#   Cell In[21], line 1
#     - we have two types of scaling
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# **z-score**

# %%
#step-1: read pwage column x
#step-2:calculate mean pwage
#step-3:calculate std of wage
#step-4:pwage-mean
#step-5: visa_df[p_z]
#step-4/step-5

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=Wage_data.mean()
wage_std=Wage_data.std()
visa_df['prevailing_wage_z']=(wage_data-wage_mean)/wage_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 wage_data=visa_df['prevailing_wage']
#       2 wage_mean=Wage_data.mean()
#       3 wage_std=Wage_data.std()
#
# NameError: name 'visa_df' is not defined

# %%
visa_df[['prevailing_wage','prevailing_wage_z']]

# %%
plt.subplot(2,2,1).hist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.subplot(2,2,1).hist
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **sklearn**
#   -preprocessing
#     standardScalar
#  - import the method
#  - save the method
# - apply the fit_transform

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
visa_df['prevailing_wage_ss']=ss.fit_transform(visa_df[['prevailing_wage']])

# %%
visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
#
# NameError: name 'visa_df' is not defined

# %% [markdown]
# **Normailization**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path='visa.csv'
visa_df = pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=Wage_data.mean()
wage_std=Wage_data.std()
visa_df['prevailing_wage_z']=(wage_data-wage_mean)/wage_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 wage_data=visa_df['prevailing_wage']
# ----> 2 wage_mean=Wage_data.mean()
#       3 wage_std=Wage_data.std()
#       4 visa_df['prevailing_wage_z']=(wage_data-wage_mean)/wage_std
#
# NameError: name 'Wage_data' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
visa_df['prevailing_wage_mm']=mm.fit_transform(visa_df[['prevailing_wage']])

# %%
visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['prevailing_wage_z', 'prevailing_wage_ss'] not in index"
